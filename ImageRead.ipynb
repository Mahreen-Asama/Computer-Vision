# %%
import cv2 as cv
import matplotlib.pylab as plt
img=plt.imread('cat1.jpg')
plt.imshow(img)

# %%
type(img)
img.shape
img.size
img.dtype
img
# Out:
# array([[[180, 198, 208],
#         [180, 198, 208],
#         [180, 198, 208],
#         ...,
#         [202, 220, 230],
#         [202, 220, 230],
#         [202, 220, 230]],
#
#        [[180, 198, 208],
#         [180, 198, 208],
#         [180, 198, 208],
#         ...,
#         [202, 220, 230],
#         [202, 220, 230],
#         [202, 220, 230]],
#
#        [[179, 197, 207],
#         [179, 197, 207],
#         [179, 197, 207],
#         ...,
#         [202, 220, 230],
#         [202, 220, 230],
#         [202, 220, 230]],
#
#        ...,
#
#        [[189, 207, 219],
#         [189, 207, 219],
#         [189, 207, 219],
#         ...,
#         [207, 221, 230],
#         [207, 221, 230],
#         [207, 221, 230]],
#
#        [[189, 207, 219],
#         [189, 207, 219],
#         [189, 207, 219],
#         ...,
#         [208, 222, 231],
#         [207, 221, 230],
#         [207, 221, 230]],
#
#        [[189, 207, 219],
#         [189, 207, 219],
#         [189, 207, 219],
# ...

# %%
img.min()
# Out:
# 0

# %%
img.max()
# Out:
# 255

# %%
img.mean()
# Out:
# 207.48789508788448

# %%
img[0,0]
# Out:
# array([180, 198, 208], dtype=uint8)

# %%
type(img[0,0])
# Out:
# numpy.ndarray

# %%
img[0,0,0]
# Out:
# 180

# %%
img[0,0,1]
# Out:
# 198

# %%
img[0,0,2]
# Out:
# 208

# %%
r=img[:,:,1]
r.shape
# Out:
# (1062, 1600)

# %%
plt.imshow(r)#it is because openCV itself creates its layer upon picture(rest channels were not zero, so showing mixed color)

# %%
plt.imshow(r,cmap='gray')

# %%
import numpy as np
aap=np.zeros(img.shape)
aap[:,:,0]=r
plt.imshow(aap)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
